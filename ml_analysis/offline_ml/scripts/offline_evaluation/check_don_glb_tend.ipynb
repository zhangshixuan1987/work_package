# %%
pip install netcdf4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xarray
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
import numpy as np
import time
import netCDF4
import matplotlib.pyplot as plt
import xarray as xr

# %%
#ds1 = xr.open_dataset('/global/cfs/cdirs/e3sm/www/zhan391/darpa_temporary_data_share/FV_180x360/E3SMv2_NDGUV_tau6_3hourly_201201010000-201212311500.nc',decode_times=False)
#print(ds1)
#U_raw_in = ds1['U_bf_ndg'][]
#print(U_raw_in.shape)
#ds2 = xr.open_dataset('/global/cfs/cdirs/e3sm/www/zhan391/darpa_temporary_data_share/FV_180x360/E3SMv2_NDGUV_tau6_3hourly_201201010300-201212311800.nc',decode_times=False)
#print(ds2)
#U_raw_in = ds2['U_bf_ndg'][]
#print(U_raw_in.shape)

# %%
U_bf_ndg_vito1 = np.load('/pscratch/sd/z/zhan391/DARPA_project/e3sm_model/code/deepONet/fortran_e3sm_vito_glb/check_python_input/U_bf_2009.npy',allow_pickle=True)
print(U_bf_ndg_vito1.shape)
plt.contourf(U_bf_ndg_vito1[0,:,:])
plt.colorbar()
# Out:
# (2920, 72, 21600)

# %%
varnam='U_bf_ndg'
ds1 = xr.open_dataset('/global/cfs/cdirs/e3sm/www/zhan391/darpa_temporary_data_share/SE_PG2/before_nudging/E3SMv2_NDGUV_tau6_3hourly_200901010000-200912312100.nc',decode_times=False)
#print(ds1)
U_bf_ndg_vito1 = ds1[varnam]
print(U_bf_ndg_vito1.shape)
plt.contourf(U_bf_ndg_vito1[0,:,:])
plt.colorbar()
# Out:
# (2920, 72, 21600)

# %%
#varnam='U_bf_ndg'
#ds1 = xr.open_dataset('/pscratch/sd/z/zhan391/DARPA_project/e3sm_model/code/deepONet/fortran_e3sm_vito_glb/check_python_input/ml_train_vito_input_'+varnam+'.nc',decode_times=False)
##print(ds1)
#U_bf_ndg_vito1 = ds1[varnam]
#print(U_bf_ndg_vito1.shape)
#plt.contourf(U_bf_ndg_vito1[0,:,:])
#plt.colorbar()

# %%
U_ndg_vito1 = np.load('/pscratch/sd/z/zhan391/DARPA_project/e3sm_model/code/deepONet/fortran_e3sm_vito_glb/raw_model_input/Nudge_U.npy',allow_pickle=True)
print(U_ndg_vito1.shape)
plt.contourf(U_ndg_vito1[0,:,:])
plt.colorbar()
# Out:
# (10, 72, 21600)

# %%
varnam='Nudge_U'
ds2 = xr.open_dataset('/pscratch/sd/z/zhan391/DARPA_project/e3sm_model/code/deepONet/fortran_e3sm_vito_glb/raw_model_input/ml_train_vito_input_'+varnam+'.nc',decode_times=False)
#print(ds1)
Nudge_U_vito1 = ds2[varnam]
print(Nudge_U_vito1.shape)
print(np.min(Nudge_U_vito1),np.max(Nudge_U_vito1))
plt.contourf(Nudge_U_vito1[0,:,:])
plt.colorbar()
# Out:
# (10, 72, 21600)
# <xarray.DataArray 'Nudge_U' ()>
# array(-0.00119514) <xarray.DataArray 'Nudge_U' ()>
# array(0.00145051)

# %%
U_ndg_vito1 = np.load('/pscratch/sd/z/zhan391/DARPA_project/e3sm_model/code/deepONet/fortran_e3sm_vito_glb/raw_model_input/Nudge_U.npy',allow_pickle=True)
print(U_ndg_vito1.shape)
plt.contourf(U_ndg_vito1[0,:,:])
plt.colorbar()
# Out:
# (10, 72, 21600)

# %%
U_fcst_ndg_vito = np.load('/pscratch/sd/z/zhan391/DARPA_project/e3sm_model/code/deepONet/fortran_e3sm_vito_glb/check_python_input/Ndg_U_pred.npy',allow_pickle=True)
print(U_fcst_ndg_vito.shape)
plt.contourf(U_fcst_ndg_vito[0,:,:])
plt.colorbar()
# Out:
# (25, 72, 21600)

# %%
varin='U'
varnam='Nudge_U'
ds2 = xr.open_dataset('/pscratch/sd/z/zhan391/DARPA_project/e3sm_model/code/deepONet/fortran_e3sm_vito_glb/'+varin+'/DeepONet_OUT_'+varnam+'.h0.2012-10-21-00000.nc',decode_times=False)
#print(ds1)
U_vito_fcst = ds2[varnam]
print(U_vito_fcst.shape)
print(np.min(U_vito_fcst),np.max(U_vito_fcst))
plt.contourf(U_vito_fcst[0,:,:])
plt.colorbar()
# Out:
# (1, 72, 21600)
# <xarray.DataArray 'Nudge_U' ()>
# array(-0.0006436) <xarray.DataArray 'Nudge_U' ()>
# array(0.00058429)

# %%
#U_bf_ndg_vito1 = np.load('/pscratch/sd/z/zhan391/DARPA_project/e3sm_model/code/deepONet/fortran_e3sm_vito_patch/raw_model_input/U_bf_ndg.npy',allow_pickle=True)
#print(U_bf_ndg_vito1.shape)
#plt.contourf(U_bf_ndg_vito1[0,46,:,:])
#plt.colorbar()
varnam='V_bf_ndg'
ds1 = xr.open_dataset('/global/cfs/cdirs/e3sm/www/zhan391/darpa_temporary_data_share/SE_PG2/before_nudging/E3SMv2_NDGUV_tau6_3hourly_200901010000-200912312100.nc',decode_times=False)
#print(ds1)
V_bf_ndg_vito1 = ds1[varnam]
print(V_bf_ndg_vito1.shape)
plt.contourf(V_bf_ndg_vito1[0,:,:])
plt.colorbar()
# Out:
# (2920, 72, 21600)

# %%
varnam='V_bf_ndg'
ds1 = xr.open_dataset('/pscratch/sd/z/zhan391/DARPA_project/e3sm_model/code/deepONet/fortran_e3sm_vito_glb/raw_model_input/ml_train_vito_input_'+varnam+'.nc',decode_times=False)
#print(ds1)
V_bf_ndg_vito1 = ds1[varnam]
print(V_bf_ndg_vito1.shape)
plt.contourf(V_bf_ndg_vito1[0,:,:])
plt.colorbar()
# Out:
# (10, 72, 21600)

# %%
varnam='Nudge_V'
ds2 = xr.open_dataset('/pscratch/sd/z/zhan391/DARPA_project/e3sm_model/code/deepONet/fortran_e3sm_vito_glb/raw_model_input/ml_train_vito_input_'+varnam+'.nc',decode_times=False)
#print(ds1)
Nudge_V_vito1 = ds2[varnam]
print(Nudge_V_vito1.shape)
print(np.min(Nudge_V_vito1),np.max(Nudge_V_vito1))
plt.contourf(Nudge_V_vito1[0,:,:])
plt.colorbar()
# Out:
# (10, 72, 21600)
# <xarray.DataArray 'Nudge_V' ()>
# array(-0.00131094) <xarray.DataArray 'Nudge_V' ()>
# array(0.00094846)

# %%
varin='V'
varnam='Nudge_V'
ds2 = xr.open_dataset('/pscratch/sd/z/zhan391/DARPA_project/e3sm_model/code/deepONet/fortran_e3sm_vito_glb/'+varin+'/DeepONet_OUT_'+varnam+'.h0.2012-10-21-00000.nc',decode_times=False)
#print(ds1)
V_vito_fcst = ds2[varnam]
print(V_vito_fcst.shape)
print(np.min(V_vito_fcst),np.max(V_vito_fcst))
plt.contourf(V_vito_fcst[0,:,:])
plt.colorbar()
# Out:
# (1, 72, 21600)
# <xarray.DataArray 'Nudge_V' ()>
# array(-0.0004871) <xarray.DataArray 'Nudge_V' ()>
# array(0.00040001)

# %%
V_bf_ndg_vito = np.load('/pscratch/sd/z/zhan391/DARPA_project/e3sm_model/code/deepONet/fortran_e3sm_vito_glb/python/vito_V_global_ndg_pred.npy',allow_pickle=True)
print(V_bf_ndg_vito.shape)
plt.contourf(V_bf_ndg_vito[0,:,:])
plt.colorbar()
# Out:
# (10, 72, 21600)
