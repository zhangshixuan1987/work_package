# %%
conda create -y  -n xcdat_jupter python=3.10
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: linux-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /global/homes/z/zhan391/.conda/envs/xcdat_jupter
#
#   added / updated specs:
#     - python=3.10
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      conda-forge/linux-64::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-2_gnu
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-hd590300_5
#   ca-certificates    conda-forge/linux-64::ca-certificates-2024.2.2-hbcca054_0
#   ld_impl_linux-64   conda-forge/linux-64::ld_impl_linux-64-2.40-h55db66e_0
#   libffi             conda-forge/linux-64::libffi-3.4.2-h7f98852_5
#   libgcc-ng          conda-forge/linux-64::libgcc-ng-13.2.0-h77fa898_7
#   libgomp            conda-forge/linux-64::libgomp-13.2.0-h77fa898_7
#   libnsl             conda-forge/linux-64::libnsl-2.0.1-hd590300_0
# ...

# %%
conda activate xcdat_jupter
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install --prefix=/global/homes/z/zhan391/.conda/envs/xcdat_jupter -c conda-forge xarray netcdf4 nco xcdat xesmf matplotlib nc-time-axis ipython ipykernel
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: linux-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /global/homes/z/zhan391/.conda/envs/xcdat_jupter
#
#   added / updated specs:
#     - ipykernel
#     - ipython
#     - matplotlib
#     - nc-time-axis
#     - nco
#     - netcdf4
#     - xarray
#     - xcdat
#     - xesmf
#
#
# The following NEW packages will be INSTALLED:
#
#   alsa-lib           conda-forge/linux-64::alsa-lib-1.2.11-hd590300_1
#   asttokens          conda-forge/noarch::asttokens-2.4.1-pyhd8ed1ab_0
#   attr               conda-forge/linux-64::attr-2.5.1-h166bdaf_1
#   aws-c-auth         conda-forge/linux-64::aws-c-auth-0.7.20-h5f1c8d9_0
#   aws-c-cal          conda-forge/linux-64::aws-c-cal-0.6.12-h2ba76a8_0
#   aws-c-common       conda-forge/linux-64::aws-c-common-0.9.17-h4ab18f5_0
#   aws-c-compression  conda-forge/linux-64::aws-c-compression-0.2.18-h36a0aea_4
# ...

# %%
#under your HPC or local terminal window, execuate following command: 
#python -m ipykernel install --user --name <ENV NAME> --display-name <ENV NAME>
python -m ipykernel install --user --name xcdat_jupter --display-name xcdat_jupter
#After above step, you can launch the xcdat_jupter from jupter Launcher section, and then run the example script
# Out:
# Note: you may need to restart the kernel to use updated packages.
